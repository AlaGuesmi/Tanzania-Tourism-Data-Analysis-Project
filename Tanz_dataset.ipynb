# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Tanzania.csv')
df.head(6)
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
# 5  tour_1005  UNITED KINGDOM     25-44                NaN           0.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
# 5         1.0            Leisure and Holidays  Wildlife tourism
#
# ...

# %%
transposed_df=df.T
transposed_df.head()
# Out:
#                            0               1               2     \
# ID                       tour_0         tour_10       tour_1000
# country              SWIZERLAND  UNITED KINGDOM  UNITED KINGDOM
# age_group                 45-64           25-44           25-44
# travel_with   Friends/Relatives             NaN           Alone
# total_female                1.0             1.0             0.0
#
#                         3          4               5             6     \
# ID                 tour_1002  tour_1004       tour_1005     tour_1007
# country       UNITED KINGDOM      CHINA  UNITED KINGDOM  SOUTH AFRICA
# age_group              25-44       1-24           25-44         45-64
# travel_with           Spouse        NaN             NaN         Alone
# total_female             1.0        1.0             0.0           0.0
#
#                                   7         8          9     ...  \
# ID                           tour_1008  tour_101  tour_1011  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'country', 'age_group', 'travel_with', 'total_female',
#        'total_male', 'purpose', 'main_activity', 'info_source',
#        'tour_arrangement', 'package_transport_int', 'package_accomodation',
#        'package_food', 'package_transport_tz', 'package_sightseeing',
#        'package_guided_tour', 'package_insurance', 'night_mainland',
#        'night_zanzibar', 'payment_mode', 'first_trip_tz', 'most_impressing',
#        'total_cost'],
#       dtype='object')

# %%
df.shape
# Out:
# (4809, 23)

# %%
#summary statistics
df.describe() #considers numercial variables only
# Out:
#        total_female   total_male  night_mainland  night_zanzibar    total_cost
# count   4809.000000  4809.000000     4809.000000     4809.000000  4.809000e+03
# mean       0.926758     1.009575        8.488043        2.304429  8.114389e+06
# std        1.287840     1.138273       10.427624        4.227080  1.222490e+07
# min        0.000000     0.000000        0.000000        0.000000  4.900000e+04
# 25%        0.000000     1.000000        3.000000        0.000000  8.121750e+05
# 50%        1.000000     1.000000        6.000000        0.000000  3.397875e+06
# 75%        1.000000     1.000000       11.000000        4.000000  9.945000e+06
# max       49.000000    44.000000      145.000000       61.000000  9.953288e+07

# %%
categorical_col=df.select_dtypes(include='object').columns
categorical_col
# Out:
# Index(['ID', 'country', 'age_group', 'travel_with', 'purpose', 'main_activity',
#        'info_source', 'tour_arrangement', 'package_transport_int',
#        'package_accomodation', 'package_food', 'package_transport_tz',
#        'package_sightseeing', 'package_guided_tour', 'package_insurance',
#        'payment_mode', 'first_trip_tz', 'most_impressing'],
#       dtype='object')

# %%
#identifying columns that contain missing values
mv=df.isnull().sum()
mv
# Out:
# ID                          0
# country                     0
# age_group                   0
# travel_with              1114
# total_female                3
# total_male                  5
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# payment_mode                0
# first_trip_tz               0
# most_impressing           313
# total_cost                  0
# dtype: int64

# %%
df['travel_with']=df['travel_with'].fillna(df['travel_with'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID                         0
# country                    0
# age_group                  0
# travel_with                0
# total_female               3
# total_male                 5
# purpose                    0
# main_activity              0
# info_source                0
# tour_arrangement           0
# package_transport_int      0
# package_accomodation       0
# package_food               0
# package_transport_tz       0
# package_sightseeing        0
# package_guided_tour        0
# package_insurance          0
# night_mainland             0
# night_zanzibar             0
# payment_mode               0
# first_trip_tz              0
# most_impressing          313
# total_cost                 0
# dtype: int64

# %%
df['most_impressing']=df['most_impressing'].fillna(df['most_impressing'].value_counts().idxmax())

# %%
df.isnull().sum()
# Out:
# ID                       0
# country                  0
# age_group                0
# travel_with              0
# total_female             3
# total_male               5
# purpose                  0
# main_activity            0
# info_source              0
# tour_arrangement         0
# package_transport_int    0
# package_accomodation     0
# package_food             0
# package_transport_tz     0
# package_sightseeing      0
# package_guided_tour      0
# package_insurance        0
# night_mainland           0
# night_zanzibar           0
# payment_mode             0
# first_trip_tz            0
# most_impressing          0
# total_cost               0
# dtype: int64

# %%
for col in ['total_female','total_male']:
    df[col]=df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# ID                       0
# country                  0
# age_group                0
# travel_with              0
# total_female             0
# total_male               0
# purpose                  0
# main_activity            0
# info_source              0
# tour_arrangement         0
# package_transport_int    0
# package_accomodation     0
# package_food             0
# package_transport_tz     0
# package_sightseeing      0
# package_guided_tour      0
# package_insurance        0
# night_mainland           0
# night_zanzibar           0
# payment_mode             0
# first_trip_tz            0
# most_impressing          0
# total_cost               0
# dtype: int64

# %%
sum(df.isnull().sum())
# Out:
# 0

# %%
#number of duplicated rows
sum(df.duplicated())
# Out:
# 0

# %%
#drop duplicated columns
df=df.drop_duplicates()
sum(df.duplicated())
# Out:
# 0

# %%
df.drop(columns='ID') #ID is irrelevant to the main aim of the problem: prediction of expenditure
# Out:
#                        country age_group        travel_with  total_female  \
# 0                   SWIZERLAND     45-64  Friends/Relatives           1.0
# 1               UNITED KINGDOM     25-44              Alone           1.0
# 2               UNITED KINGDOM     25-44              Alone           0.0
# 3               UNITED KINGDOM     25-44             Spouse           1.0
# 4                        CHINA      1-24              Alone           1.0
# ...                        ...       ...                ...           ...
# 4804                       UAE     45-64              Alone           0.0
# 4805  UNITED STATES OF AMERICA     25-44             Spouse           1.0
# 4806               NETHERLANDS      1-24              Alone           1.0
# 4807              SOUTH AFRICA     25-44  Friends/Relatives           1.0
# 4808            UNITED KINGDOM     25-44             Spouse           1.0
#
#       total_male                         purpose     main_activity  \
# ...

# %%
import klib
klib.corr_plot(df)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
numerical_col=df.select_dtypes(include='number').columns
numerical_col
# Out:
# Index(['total_female', 'total_male', 'night_mainland', 'night_zanzibar',
#        'total_cost'],
#       dtype='object')

# %%
df['country'].value_counts().head(3)
# Out:
# country
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# Name: count, dtype: int64

# %%
df['age_group'].value_counts().idxmax() #index of maximum value
# Out:
# '25-44'

# %%
#most commonly visited place by age group
df.groupby(by=['age_group'])['purpose'].apply(lambda x:x.value_counts().idxmax()) #apply() or agg()
#most occured value: value_counts().idxmax()
#least occured values: value_counts().idxmin()
# Out:
# age_group
# 1-24     Leisure and Holidays
# 25-44    Leisure and Holidays
# 45-64    Leisure and Holidays
# 65+      Leisure and Holidays
# Name: purpose, dtype: object

# %%
df_grouped=df.groupby(by=['country'])['total_cost'].sum()
dic={df_grouped.idxmax():float(df_grouped.max())}
dic
# Out:
# {'UNITED STATES OF AMERICA': 8890832053.7}

# %%
#max of the total expenditure
df.groupby(by=['country'])['total_cost'].max()
# Out:
# country
# ALGERIA                      3734347.5
# ANGOLA                        500000.0
# ARGENTINA                   10442250.0
# AUSTRALIA                   66963000.0
# AUSTRIA                     23205000.0
#                                ...
# UNITED STATES OF AMERICA    86190000.0
# URUGUAY                       165750.0
# YEMEN                         248625.0
# ZAMBIA                      42100500.0
# ZIMBABWE                    58344000.0
# Name: total_cost, Length: 105, dtype: float64

# %%
max_total_expenditure_by_country=df.groupby(by=['country'])['total_cost'].sum().max()
float(max_total_expenditure_by_country)
# Out:
# 8890832053.7

# %%
#dataframe that contains only the Indepedent travelers
#1st method
indep_df=df[df['tour_arrangement']=='Independent']
indep_df
# Out:
#              ID         country age_group        travel_with  total_female  \
# 0        tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1       tour_10  UNITED KINGDOM     25-44              Alone           1.0
# 2     tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 4     tour_1004           CHINA      1-24              Alone           1.0
# 6     tour_1007    SOUTH AFRICA     45-64              Alone           0.0
# ...         ...             ...       ...                ...           ...
# 4802    tour_99           KENYA     45-64  Friends/Relatives           2.0
# 4803   tour_991         GERMANY      1-24  Friends/Relatives           2.0
# 4804   tour_993             UAE     45-64              Alone           0.0
# 4806   tour_995     NETHERLANDS      1-24              Alone           1.0
# 4807   tour_997    SOUTH AFRICA     25-44  Friends/Relatives           1.0
#
# ...

# %%
#dataframe that contains only the Indepedent travelers
#2nd method
df_query=df.query("tour_arrangement =='Independent'")
df_query
# Out:
#              ID         country age_group        travel_with  total_female  \
# 0        tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1       tour_10  UNITED KINGDOM     25-44              Alone           1.0
# 2     tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 4     tour_1004           CHINA      1-24              Alone           1.0
# 6     tour_1007    SOUTH AFRICA     45-64              Alone           0.0
# ...         ...             ...       ...                ...           ...
# 4802    tour_99           KENYA     45-64  Friends/Relatives           2.0
# 4803   tour_991         GERMANY      1-24  Friends/Relatives           2.0
# 4804   tour_993             UAE     45-64              Alone           0.0
# 4806   tour_995     NETHERLANDS      1-24              Alone           1.0
# 4807   tour_997    SOUTH AFRICA     25-44  Friends/Relatives           1.0
#
# ...
